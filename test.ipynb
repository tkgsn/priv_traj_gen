# %%
# show /data/results/peopleflow/100000/bin38/baseline/generated_empirical_next_location_distribution_1031.png

import matplotlib.pyplot as plt

def plot_empirical_next_location_distribution(location):
    path = f"/data/results/peopleflow/100000/bin38/real_next_location_distribution_{location}.png"
    img = plt.imread(path)
    plt.imshow(img)
    plt.show()

    path = f"/data/results/peopleflow/100000/bin38/baseline/generated_empirical_next_location_distribution_{location}.png"
    img = plt.imread(path)
    plt.imshow(img)
    plt.show()

# %%
location = 622
plot_empirical_next_location_distribution(location)
